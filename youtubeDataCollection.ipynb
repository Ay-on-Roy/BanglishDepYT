# %%
# !pip install google-api-python-client langdetect emoji pandas

# %%
# CELL — Comprehensive Bengali Depression Query Bank

DEPRESSIVE_QUERIES = {

    # ── 1. Direct emotional expression ───────────────────────
    "direct_emotion": [
        "অকারণে কান্না",
        "অন্ধকার লাগছে",
        "অনুভূতি মরে গেছে",
        "আমি আর সহ্য করতে পারছি না",
        "আমি একটা জিন্দা লাশ",
        "আমি একটা বোঝা",
        "আমি ক্লান্ত",
        "আমি খুব আনলাকি",
        "আমি খুব একা",
        "আমি খুব ক্লান্ত",
        "আমি খুব দুর্বল",
        "আমি দিশেহারা",
        "আমি পাথর হয়ে গেছি",
        "আমি পাগল হয়ে যাব",
        "আমি ফালতু",
        "আমি বিরক্ত",
        "আমি মূল্যহীন",
        "আমি শূন্য",
        "আমি শুধু কষ্ট পাই",
        "আমি শুধু বোঝা বাড়াচ্ছি",
        "আমি হার মেনে গেছি",
        "আমি হাসতে ভুলে গেছি",
        "আমি হেরে গেছি",
        "আর পারছি না",
        "একা লাগছে",
        "কষ্ট লাগছে",
        "কষ্টের শেষ নেই",
        "কাঁদছি",
        "কান্না আটকে রাখা",
        "কান্না থামছে না",
        "কোথাও শান্তি নেই",
        "খুব অসহায় লাগছে",
        "খুব একা আমি",
        "গুমরে কাঁদা",
        "চিৎকার করে কাঁদতে ইচ্ছে করছে",
        "জীবন অর্থহীন",
        "দম বন্ধ হয়ে আসছে",
        "নিঃসঙ্গ লাগছে",
        "নিজেকে ঘেন্না লাগে",
        "নিজেকে শেষ করতে চাই",
        "নিজেকে হারিয়ে ফেলেছি",
        "বুক ফেটে যাচ্ছে",
        "বুকে ব্যথা",
        "বুকের ভেতর পাথর",
        "বেঁচে থেকে লাভ কী",
        "বাঁচতে ইচ্ছে করছে না",
        "ভালো নেই",
        "ভিতরে ভিতরে মরে গেছি",
        "ভেতরে ভেতরে কষ্ট",
        "মন খারাপ",
        "সব অন্ধকার",
        "সব শেষ",
        "সবাই আমাকে অবহেলা করে",
        "সবাই আমাকে ঠকায়",
        "সবাই আমাকে ভুল বোঝে",
        "সবকিছু মিথ্যা",
        "শেষ হয়ে যেতে চাই",
        "শূন্যতা",
        "হতাশা",
    ],

    # ── 2. Banglish / code-mixed queries ─────────────────────
    "banglish": [
        "ami akta loser",
        "ami ekta opadartho",
        "ami eka hoye gechi",
        "ami ekti boza",
        "ami hariye gechi",
        "ami just tired",
        "ami keno emon",
        "ami khub eka",
        "ami khub helpless",
        "ami khub oshohel",
        "ami klanto",
        "ami shob nosto kori",
        "ami tuccho",
        "amk keu chine na",
        "amr kono value nai",
        "amr thaka na thaka eki",
        "anxiety bangla",
        "bachte chai na r",
        "bhitore bhitore morsi",
        "bhitore bhitore sesh",
        "buke betha",
        "crying alone at night",
        "crying alone bangla",
        "depressed vai",
        "depression bangla",
        "ekla lagche",
        "emotionally broken",
        "fake smile dilam",
        "heartbroken bangla story",
        "help lagbe",
        "jibon ta britha",
        "jibon ta narak",
        "jibon ta tej pata",
        "jibon tai ektu vul",
        "kanna pacche",
        "kanna আসছে",
        "keu bujhbe na",
        "keu pashe nai",
        "kew amk bujhena",
        "kew amk chay na",
        "kew nai amar",
        "kew valobashe na",
        "kno bache asi",
        "kosto gulo kake bolbo",
        "kosto gulo r nite parchi na",
        "kosto lagche",
        "kosto pain",
        "life shesh",
        "mara jete icche kore",
        "mental health bangla",
        "mentally dead",
        "mon kharap bangla",
        "morle bachi",
        "nijer upor rag hoy",
        "nirash ami",
        "nobody cares about me",
        "onek kosto",
        "r partesi na",
        "r valo lage na",
        "sad feeling bangla",
        "shanti nai ektu o",
        "shob amar dosh",
        "sob sesh",
        "sob somoy kosto",
        "sobai fake",
        "suicidal thoughts ashe",
        "valo nei ami",
        "why am i like this",
    ],

    # ── 3. Cognitive distortions / Negative thinking ─────────
    "cognitive_distortions": [
        "amar jonno sob noshto hoy",
        "ami konodin change hobo na",
        "ami unlucky sob somoy",
        "everyone is better than me",
        "i always mess things up",
        "i am the problem",
        "i don't deserve anything good",
        "nothing will ever get better",
        "sob shomoy amar sathei kharap hoy",
        "আমার কোনো ভবিষ্যৎ নেই",
        "আমার জন্যই সব নষ্ট হয়",
        "আমার ভাগ্যে ভালো কিছু নেই",
        "আমি এমনই খারাপ",
        "আমি কখনো কিছু ঠিক করতে পারি না",
        "আমি বদলাতে পারব না",
        "আমি সব সময় ভুল করি",
        "আমি কিছুতেই সফল হব না",
        "আমি সবসময় পিছিয়ে থাকি",
        "সব আমার দোষ",
        "সব কিছুই খারাপ হবে",
        "সবাই আমার থেকে ভালো",
    ],

    # ── 4. Loss of interest / Anhedonia ─────────────────────
    "anhedonia": [
        "age ja bhalo lagto ekhon lage na",
        "everything feels pointless",
        "hobby gula dead hoye geche",
        "i feel bored all the time",
        "kichu te interest pai na",
        "life e kono moja nai",
        "nothing feels fun anymore",
        "আগের মতো ভালো লাগে না",
        "কিছুতেই আনন্দ পাই না",
        "কোনো কিছুতে excitement নেই",
        "শখগুলো আর ভালো লাগে না",
        "সবকিছু বিরক্তিকর লাগে",
    ],

    # ── 5. Emotional numbness / Dissociation ────────────────
    "emotional_numbness": [
        "ami numb hoye gechi",
        "emotionless hoye gechi",
        "feel nothing inside",
        "kichu feel kori na ekdom",
        "like i am not real",
        "অনুভূতি নেই",
        "আমি রোবটের মতো হয়ে গেছি",
        "কিছুই অনুভব করি না",
        "নিজেকে নিজের মতো লাগে না",
        "মনটা একদম ফাঁকা",
        "সবকিছু স্বপ্নের মতো লাগে",
        "হাসি কান্না কিছুই আসে না",
    ],

    # ── 6. Life situations causing depression ────────────────
    "life_situations": [
        "অনাথ হওয়ার কষ্ট",
        "অন্ধকার ভবিষ্যৎ",
        "অপমানিত হয়েছি",
        "অফিসে পলিটিক্স",
        "অ্যাক্সিডেন্টের পর",
        "ক্যারিয়ার ধ্বংস",
        "কেউ দাম দেয় না",
        "কেউ পাশে নেই",
        "খাওয়ার টাকা নেই",
        "গরিব হওয়ার কষ্ট",
        "চাকরি চলে গেছে",
        "চাকরি নেই",
        "চাকরির ইন্টারভিউতে রিজেক্ট",
        "চুরি হয়ে গেছে",
        "জমানো টাকা শেষ",
        "জমি জমা নিয়ে ঝামেলা",
        "জেলে যাওয়ার ভয়",
        "টাকার অভাবে চিকিৎসা হচ্ছে না",
        "টাকার সমস্যা কষ্ট",
        "ডিভোর্সের পর",
        "ধার শোধ করতে পারছি না",
        "পঙ্গু হওয়ার কষ্ট",
        "পরিবার বোঝে না",
        "পরিবারের অশান্তি",
        "পরিবারের বোঝা",
        "পরীক্ষায় ফেল",
        "পারিবারিক কলহ",
        "প্রতারিত হয়েছি",
        "প্রবাস জীবন কষ্ট",
        "প্রমোশন না পাওয়া",
        "প্রিয়জন হারানো",
        "প্রিয়জনের মৃত্যুশোক",
        "প্রেম ভেঙে গেছে",
        "বন্ধ্যত্বের কষ্ট",
        "বন্ধুরা ধোঁকা দিয়েছে",
        "বন্ধু নেই",
        "বাবার বকা",
        "বাবার মৃত্যু",
        "বাবা মা মারা গেছে",
        "বাবাকে মিস করছি",
        "বাচ্চা মারা গেছে",
        "বিদেশে একাকীত্ব",
        "বিচ্ছেদের পর",
        "বিয়ে ভেঙে গেছে",
        "বিয়ে হচ্ছে না হতাশা",
        "বিশ্বাসঘাতকতা কষ্ট",
        "বেকারত্বের অভিশাপ",
        "ব্যবসা পুড়ে গেছে",
        "ব্যবসায় লস",
        "ব্যর্থতার কষ্ট",
        "বোনের মৃত্যু",
        "ভাইয়ের মৃত্যু",
        "ভাড়া দিতে পারছি না",
        "মায়ের মৃত্যু",
        "মা বাবার বিচ্ছেদ",
        "মাকে মনে পড়ছে",
        "মানসম্মান শেষ",
        "মানসিক নির্যাতন",
        "মিথ্যা অপবাদ",
        "রাস্তায় নেমে গেছি",
        "লক্ষ্য পূরণ হয়নি",
        "শারীরিক অসুস্থতা",
        "সব টাকা হারিয়েছি",
        "সবাই পাওনাদার",
        "সমাজ কী বলবে",
        "সম্মান নষ্ট",
        "সন্তান না হওয়ার দুঃখ",
        "স্বামী স্ত্রীর ঝগড়া",
        "স্বপ্ন ভেঙে গেছে",
        "আত্মীয়দের খোঁচা",
    ],

    # ── 7. Irritability / Anger linked to depression ────────
    "irritability": [
        "ami khub irritate hoye jai",
        "everything pisses me off",
        "i get angry for no reason",
        "sob kichu annoying lage",
        "কেউ কিছু বললেই রাগ লাগে",
        "ছোট ছোট ব্যাপারে রাগ হচ্ছে",
        "নিজেকে কন্ট্রোল করতে পারি না",
        "মেজাজ সবসময় খারাপ",
        "সবকিছুতে বিরক্ত লাগে",
        "হঠাৎ রাগ উঠে যায়",
    ],

    # ── 8. Social withdrawal / Isolation behavior ───────────
    "social_withdrawal": [
        "i avoid everyone",
        "i just want to be alone",
        "manusher majhe gele awkward lage",
        "message reply dite iccha kore na",
        "phone dhorte iccha kore na",
        "social hote iccha kore na",
        "একাই থাকতে ভালো লাগে",
        "কারও সাথে কথা বলতে ইচ্ছা করে না",
        "মানুষ এড়িয়ে চলি",
        "সবাই থেকে দূরে থাকতে চাই",
    ],

    # ── 9. Guilt / Worthlessness deeper layer ───────────────
    "deep_guilt": [
        "amar thaka na thaka eki",
        "ami kono kajer na",
        "ami sudhu problem create kori",
        "i am a burden to everyone",
        "people are better without me",
        "আমি কারো জীবনে ভ্যালু যোগ করি না",
        "আমি সবার জন্য সমস্যা",
        "আমি useless",
        "আমার কারণে সবাই কষ্ট পায়",
        "নিজেকে সহ্য করতে পারি না",
    ],

    # ── 10. Future hopelessness / Pessimism ──────────────────
    "hopeless_future": [
        "amar life e kono direction nai",
        "i feel stuck in life",
        "life e kono progress nai",
        "no future for me",
        "nothing to look forward to",
        "same loop e ghurtese life",
        "আমার সামনে কিছু নেই",
        "আমি কোথাও পৌঁছাতে পারব না",
        "ভবিষ্যতে কিছুই ভালো হবে না",
        "সব রাস্তা বন্ধ",
    ],

    # ── 11. Mental Health Awareness / Treatment Searches ─────
    "mental_health_awareness": [
        "PTSD bangla",
        "addiction recovery bd",
        "antidepressant side effects bangla",
        "anxiety disorder bangla",
        "child psychologist dhaka",
        "depression কি বাংলায়",
        "family therapy bd",
        "free counseling bangladesh",
        "how to deal with depression bangla",
        "how to stop overthinking in bangla",
        "mental breakdown bangla",
        "mental health checkup",
        "mental health helpline bd",
        "online therapy bangladesh",
        "panic attack bangla",
        "postpartum depression bangla",
        "psychiatrist bangladesh bangla",
        "psychologist and psychiatrist difference bangla",
        "ptsd symptoms bangla",
        "relationship counseling bd",
        "suicide prevention hotline bd",
        "teenage counseling bangladesh",
        "therapy bangladesh",
        "therapy cost in dhaka",
        "therapy kivabe nite hoy",
        "trauma bangla",
        "trauma healing bangla",
        "অ্যাংজাইটি অ্যাটাক",
        "ওসিডি থেকে মুক্তির উপায়",
        "ক্লিনিক্যাল ডিপ্রেশন কী",
        "কিভাবে মন ভালো রাখব",
        "গর্ভকালীন বিষণ্ণতা",
        "ঘুমের ওষুধের নাম",
        "ডিপ্রেশন কাটানোর ইসলামিক উপায়",
        "ডিপ্রেশন থেকে মুক্তির উপায়",
        "ট্রমা থেকে বের হওয়ার উপায়",
        "নেগেটিভ চিন্তা দূর করার উপায়",
        "প্যানিক অ্যাটাক কেন হয়",
        "পাগল হয়ে যাওয়ার ভয়",
        "বাইপোলার ডিসঅর্ডার লক্ষণ",
        "বিষণ্ণতা দূর করার দোয়া",
        "বিষণ্নতা কি",
        "মন খারাপ কাটানোর উপায়",
        "মনোবিজ্ঞান বাংলা",
        "মনোরোগ বাংলাদেশ",
        "মাদকাসক্তি নিরাময় কেন্দ্র",
        "মানসিক অবসাদ",
        "মানসিক চাপ কমানোর উপায়",
        "মানসিক চাপ কমানোর ব্যায়াম",
        "মানসিক ডাক্তার",
        "মানসিক রোগ বাংলা",
        "মানসিক রোগের লক্ষণ",
        "মানসিক রোগীর চিকিৎসা",
        "মানসিক শক্তি বৃদ্ধির উপায়",
        "মানসিক শান্তির উপায়",
        "মানসিক সমস্যা সমাধান",
        "মানসিক স্বাস্থ্য সচেতনতা",
        "মানসিক হাসপাতাল পাবনা",
        "নিজেকে ভালোবাসার উপায়",
        "সাইকিয়াট্রিস্ট ফি",
        "সাইকোলজিস্ট ঢাকা",
        "স্লিপিং পিল এর নাম",
        "সন্তান জন্মের পর মানসিক সমস্যা",
        "স্ট্রেস ম্যানেজমেন্ট",
        "হ্যালুসিনেশন কেন হয়",
        "আত্মবিশ্বাস বাড়ানোর উপায়",
        "কাউন্সেলিং সেন্টার",
    ],

    # ── 12. Suicide and Crisis ─────────────────────────────
    "crisis": [
        "life end করতে চাই",
        "suicide bangla",
        "আত্মহত্যা কেন করে",
        "আত্মহত্যা প্রতিরোধ",
        "আত্মহত্যা মহাপাপ জেনেও মরতে চাই",
        "আত্মহত্যার চিন্তা আসছে",
        "আমাকে কেউ বাঁচতে দিচ্ছে না",
        "আমি একদম শেষ প্রান্তে",
        "আমি কবরে যেতে চাই",
        "আমি ঘুমিয়ে পড়তে চাই আর না উঠতে",
        "আমি দেয়ালে পিঠ ঠেকে গেছি",
        "আমি মরতে চাই",
        "আমি মরে গেলে কেউ কাঁদবে না",
        "আমি মরে গেলে সবাই খুশি হবে",
        "আমি মুক্তি খুঁজছি",
        "আমি মৃত্যুর জন্য অপেক্ষা করছি",
        "আমি লাশ হতে চাই",
        "আমি স্বেচ্ছামৃত্যু চাই",
        "আমার আর কিছুই হারাবার নেই",
        "আমার আর বাঁচার ইচ্ছে নাই",
        "আমার গল্প এখানেই শেষ",
        "আমার জন্য সবাই কষ্ট পায়",
        "আমার দম বের হয়ে যাক",
        "আমার মৃত্যু খুব কাছে",
        "আমার মৃত্যু দরকার",
        "আমার মৃত্যুতে কেউ কাঁদবে না",
        "আমার শরীরটা শুধু বেঁচে আছে",
        "আমার সময় শেষ",
        "আমার হায়াত শেষ করে দাও",
        "আর কয়েকটা দিন মাত্র",
        "আর থাকতে চাই না",
        "আর সহ্য হচ্ছে না",
        "আল্লাহ আমাকে তুলে নাও",
        "ঈশ্বর আমাকে নিয়ে যাও",
        "কীভাবে এই কষ্ট থেকে বাঁচব",
        "কেন বাঁচব",
        "কবর ডাকছে",
        "ক্ষমা করে দিও সবাই",
        "খুব শিগগিরই চলে যাব",
        "চিরকালের ঘুম",
        "জীবনের মানে কি",
        "নিজেকে শেষ করার চিন্তা",
        "বিদায় পৃথিবী",
        "বাঁচতে চাই না",
        "বেঁচে থাকার কোনো কারণ নেই",
        "মরে যেতে চাই",
        "মৃত্যু কামনা",
        "মৃত্যু কেন আসে না",
        "মৃত্যুই একমাত্র সমাধান",
        "মুক্তি চাই",
        "সব শেষ করে দিতে চাই",
        "সব শেষ করে দেওয়ার ইচ্ছা",
        "সবাইকে বিদায়",
        "সবাইকে মুক্তি দিতে চাই",
        "সুযোগ পেলে মরে যেতাম",
    ],

    # ── 13. Physical Symptoms & Somatic Complaints ─────────
    "physical_symptoms": [
        "brain fog bangla",
        "chronic fatigue bangla",
        "insomnia bangla",
        "sleep paralysis bangla",
        "অকারণে ঘাম হওয়া",
        "অতিরিক্ত ক্লান্তি",
        "অতিরিক্ত খাওয়া",
        "অস্থিরতা",
        "আলো সহ্য হয় না",
        "আয়নায় নিজেকে দেখতে ঘেন্না",
        "ওজন কমে যাচ্ছে",
        "ওজন বেড়ে যাওয়া ডিপ্রেশন",
        "কথা বলতে ইচ্ছা করে না",
        "ক্লান্ত লাগছে সবসময়",
        "ক্ষুধা নেই depression",
        "খাবারে অরুচি",
        "খাবারের স্বাদ নেই",
        "খালি বিছানায় পড়ে থাকি",
        "খেতে ইচ্ছে করে না",
        "গলায় কিছু আটকে আছে মনে হয়",
        "গোসল করতে ইচ্ছা করে না",
        "ঘুম আসে না রাতে",
        "ঘুম ভেঙে যায়",
        "ঘুমের মধ্যে চমকে ওঠা",
        "চোখ জ্বলে কান্নার জন্য",
        "চোখের নিচে কালি",
        "চুল ছেঁড়া",
        "চুল পড়ে যাচ্ছে চিন্তায়",
        "দুঃস্বপ্ন দেখা",
        "দম বন্ধ হয়ে আসা",
        "নখ কামড়ানো",
        "পেট খারাপ টেনশনে",
        "প্যানিক অ্যাটাক ফিজিক্যাল সিম্পটমস",
        "বুক ধড়ফড় করে",
        "বুক ভারী হয়ে থাকে",
        "বুকের বাম পাশে ব্যথা",
        "বমি বমি ভাব",
        "বোবায় ধরা",
        "মানুষের সামনে যেতে ভয় লাগে",
        "মাথা কাজ করে না",
        "মাথা ঘোরে",
        "মাথা ব্যথা stress",
        "মাথা ব্যথা সারাদিন",
        "মুখে ব্রন স্ট্রেস থেকে",
        "রাত জেগে কান্না",
        "শব্দ সহ্য হয় না",
        "শরীর দুর্বল মন খারাপ",
        "শরীরে ব্যথা",
        "শরীরে শক্তি নেই",
        "শরীরের যত্ন না নেওয়া",
        "শ্বাস নিতে কষ্ট হয়",
        "সকালে ঘুম থেকে উঠতে কষ্ট",
        "সবকিছু ভুলে যাই",
        "সারাদিন ঘুম পায়",
        "সারাদিন শুয়ে থাকি",
        "সারারাত সজাগ",
        "স্মৃতিশক্তি কমে যাচ্ছে",
        "স্ট্রেস ইটিং",
        "হার্ট অ্যাটাকের ভয়",
        "হাত পা কাঁপে",
        "হাত পা ঠান্ডা হয়ে যাওয়া",
        "নিজের যত্ন নিতে ইচ্ছা করে না",
        "কোনো কাজে মন বসে না",
    ],

    # ── 14. Personal Story / Confession ─────────────────────
    "personal_story": [
        "depression survivor bangla",
        "depression থেকে ফিরে আসা",
        "mental health journey bangla",
        "আমার breakdown এর গল্প",
        "আমার এবিউসিভ রিলেশনশিপ",
        "আমার একলা পথ চলা",
        "আমার একাকীত্বের কথা",
        "আমার একাকীত্বের রাত",
        "আমার অন্ধকার ঘর",
        "আমার আসল চেহারা",
        "আমার কষ্টের কথা",
        "আমার কষ্টের গান",
        "আমার গোপন কষ্ট",
        "আমার ছোটবেলার ট্রমা",
        "আমার ডিপ্রেশন জার্নি",
        "আমার ডিপ্রেশনের ডায়েরি",
        "আমার ডায়েরির পাতা",
        "আমার টক্সিক ফ্যামিলি",
        "আমার দুঃখের কবিতা",
        "আমার নার্সিসিস্টিক বাবা মা",
        "আমার নীরব কান্না",
        "আমার ফেক স্মাইল",
        "আমার ব্যর্থতার গল্প",
        "আমার বিষণ্নতার গল্প",
        "আমার বুলিং এর শিকার হওয়ার গল্প",
        "আমার বেঁচে ফেরার গল্প",
        "আমার বিছানায় কান্নার দাগ",
        "আমার ভাঙা মন",
        "আমার ভেজা বালিশ",
        "আমার মানসিক ট্রমা",
        "আমার মানসিক স্বাস্থ্যের গল্প",
        "আমার মুখোশ",
        "আমার লাল চোখ",
        "আমার লুকানো কষ্ট",
        "আমার সারভাইভাল স্টোরি",
        "আমার থেরাপির অভিজ্ঞতা",
        "আমার সুইসাইড অ্যাটেম্পট",
        "আমার স্বপ্নের মৃত্যু",
        "আমার সংগ্রামের গল্প",
        "আমার হেরে যাওয়ার গল্প",
        "আমি কাউকে বলতে পারি না",
        "আমি কেন মরতে চেয়েছিলাম",
        "আমি কেন সাইকিয়াট্রিস্ট এর কাছে গেলাম",
        "আমি কীভাবে ঘুরে দাঁড়ালাম",
        "আমি কীভাবে শেষ হয়ে গেলাম",
        "আমি কেন এমন",
        "আমার অপমানের প্রতিশোধ",
        "আমার ওষুধ খাওয়ার অভিজ্ঞতা",
        "আমার জীবনের অন্ধকার অধ্যায়",
        "আমার সাথে কেন এমন হয়",
        "কষ্টের স্ট্যাটাস",
        "কীভাবে depression কাটিয়ে উঠলাম",
        "কেউ আমাকে বোঝেনি",
        "কেউ শোনার নেই",
        "দুঃখের ডায়েরি",
        "নিজের সাথে যুদ্ধ",
        "মনের কথা বলতে চাই",
        "স্কুলে বুলিং",
        "হাসির পেছনের কান্না",
    ],

    # ── 15. Relationship & Loneliness ───────────────────────
    "relationship_loneliness": [
        "fomo bangla",
        "hurt feelings bangla",
        "unrequited love bangla",
        "অবহেলার কষ্ট",
        "আমাকে কেউ ভালোবাসে না",
        "আমি অপশন ছিলাম",
        "আমি একা রয়ে গেলাম",
        "আমি তাকে ভুলতে পারছি না",
        "আমি ভালোবাসার যোগ্য না",
        "আমি ইনভিজিবল",
        "আমার অস্তিত্ব নেই",
        "আমার একাকীত্ব",
        "আমার কপালে ভালোবাসা নেই",
        "আমার কোনো বেস্ট ফ্রেন্ড নেই",
        "আমার জন্য কারো সময় নেই",
        "আমার মেসেজের রিপ্লাই দেয় না",
        "আমার বিশ্বাস ভেঙেছে",
        "আমি আনওয়ান্টেড",
        "আমি আর কাউকে বিশ্বাস করি না",
        "আমি খুব একা বোধ করি",
        "আমি তার জন্য সব করেছি",
        "আমি মরে গেলে কেউ জানবেও না",
        "একতরফা ভালোবাসা",
        "একাকী রাত",
        "কেউ আমার খোঁজ নেয় না",
        "কেউ ভালোবাসে না",
        "কাছের মানুষ পর",
        "কাছের মানুষের অবহেলা",
        "গুরুত্ব না পাওয়ার কষ্ট",
        "গ্রুপে আমাকে কেউ ডাকে না",
        "চলে গেছ ব্যথা",
        "চিটিং এর শিকার",
        "তার মেসেজ পড়ি আর কাঁদি",
        "তার বিয়ে হয়ে গেছে",
        "তার স্মৃতি কাঁদায়",
        "দূরত্ব বেড়ে গেছে",
        "ধোঁকা খাওয়ার কষ্ট",
        "পিছনে নিন্দা করে",
        "প্রাক্তনকে ভোলার উপায়",
        "প্রেম মানেই কষ্ট",
        "ব্রেকআপ স্ট্যাটাস",
        "ব্রোকেন হার্ট",
        "বন্ধুত্বে ফাটল",
        "বিশ্বাস ভেঙে গেছে",
        "বিশ্বাসঘাতক",
        "বেস্ট ফ্রেন্ড ধোঁকা দিয়েছে",
        "ভুল মানুষকে ভালোবাসা",
        "ভুলতে পারছি না",
        "ভালোবাসা মিথ্যা",
        "ভালোবাসায় প্রতারণা",
        "মিস করছি তোমাকে",
        "রিলেশনশিপ ব্রেকআপ",
        "লয়্যালটি নেই",
        "সম্পর্ক শেষ",
        "সম্পর্ক ভাঙার কষ্ট",
        "সবাই আমাকে ইগনোর করে",
        "সবাই আমাকে ছেড়ে চলে যায়",
        "সবাই বিজি",
        "সবাই স্বার্থপর",
        "সবার লাইফ সুন্দর শুধু আমার ছাড়া",
        "স্যাড সং",
        "সোশ্যাল মিডিয়ায় একাকীত্ব",
        "সে অন্য কাউকে ভালোবাসে",
        "সে আমাকে ইউজ করেছে",
        "সে আমাকে ব্লক করেছে",
        "আমার সিক্রেট বলে দিয়েছে",
        "কষ্টের মেসেজ",
        "ব্লক লিস্ট",
        "প্রায়োরিটি ছিলাম না",
    ],

    # ── 16. Student / Youth Depression ─────────────────────
    "student_youth": [
        "HSC depression bangla",
        "career নিয়ে হতাশা",
        "student depression bangla",
        "teenage depression bangla",
        "university life depression",
        "young generation mental health bangladesh",
        "অ্যাসাইনমেন্ট প্রেসার",
        "আইইএলটিএস খারাপ",
        "ইঞ্জিনিয়ারিং চান্স না পাওয়া",
        "ইন্টারভিউ ভয়",
        "এক্সাম ফোবিয়া",
        "ক্যাম্পাসে মারামারি",
        "ক্যারিয়ার নিয়ে টেনশন",
        "কোটা সংস্কার আন্দোলন ট্রমা",
        "ক্লাসে কেউ কথা বলে না",
        "জিপিএ ৫ না পাওয়ার কষ্ট",
        "থিসিস প্রেসার",
        "নেতাদের ভয়",
        "পরীক্ষার আগে প্যানিক অ্যাটাক",
        "পরীক্ষার চাপ কষ্ট",
        "পলিটিক্যাল প্রেসার",
        "পাবলিক ভার্সিটি চান্স না পাওয়া",
        "পড়াশোনা ছেড়ে দিতে চাই",
        "পড়াশোনায় মন বসে না",
        "প্রাইভেট ভার্সিটি ফি",
        "প্রেজেন্টেশন ভয়",
        "ফ্যামিলির প্রেসার",
        "বন্ধুরা এগিয়ে গেছে আমি পিছিয়ে",
        "বন্ধুদের সাথে মিশতে পারি না",
        "বাবা মায়ের টাকা নষ্ট",
        "বাবা মায়ের চাপ",
        "বাবা মায়ের বকা",
        "বিসিএস হতাশা",
        "বিদেশে যাওয়ার স্বপ্ন শেষ",
        "বেকারত্ব",
        "বোর্ড এক্সাম ফেইল",
        "ভবিষ্যতে কী করব",
        "ভবিষ্যৎ নিয়ে ভয়",
        "ভর্তি পরীক্ষা ব্যর্থতা",
        "ভাইভায় অপমান",
        "ভিসা রিজেক্ট",
        "মেডিকেলে চান্স না পাওয়ার কষ্ট",
        "মেসের খাবার",
        "র‍্যাগিং এর শিকার",
        "রেজাল্ট এর দিন ভয়",
        "রেজাল্ট খারাপ",
        "শিক্ষকের দুর্ব্যবহার",
        "সরকারি চাকরির বয়স",
        "সাপ্লিমেন্টারি এক্সাম",
        "সিনিয়রদের টর্চার",
        "সেশন জট হতাশা",
        "সোশ্যাল অ্যাংজাইটি",
        "স্কলারশিপ না পাওয়া",
        "স্কিল নেই",
        "হোস্টেল লাইফ কষ্ট",
        "হোমসিকনেস",
        "সবাই আমাকে লুজার ভাবে",
        "সুপারভাইজারের বকা",
        "আত্মীয়দের রেজাল্ট জিজ্ঞেস করা",
        "আমি আনস্মার্ট",
        "আমি কিছু পারি না",
        "আমি পরিবারের কলঙ্ক",
        "আমার কোনো লক্ষ্য নেই",
        "চাকরির বয়স শেষ",
        "ড্রপআউট",
    ],

    # ── 17. Existential & Fatalistic ───────────────────────
    "miscellaneous_despair": [
        "অভাগা",
        "অভিশপ্ত জীবন",
        "আমার ক্ষমা নেই",
        "আমার দোয়া কবুল হয় না",
        "আমার নসিব খারাপ",
        "আমার ভাগ্যটাই খারাপ",
        "আমার শেষকৃত্যে কেউ আসবে না",
        "আমি অচ্ছুত",
        "আমি একা মরব",
        "আমি দোষী",
        "আমি নরকে যাব",
        "আমি পথভ্রষ্ট",
        "আমি পাপী",
        "আমি সমাজচ্যুত",
        "আমার ঈমান দুর্বল",
        "আমি নামাজ ছেড়ে দিয়েছি কষ্টে",
        "আল্লাহ আমাকে ভুলে গেছে",
        "ঈশ্বর আমার সহায় নেই",
        "কেউ আমাকে ছোঁবে না",
        "সব আমার অপরাধ",
    ],

    # ── 18. Decision Fatigue / Mental Overload ─────────────
    "mental_overload": [
        "brain overloaded",
        "decision nite bhoy lage",
        "i can't think clearly",
        "kichu bujhte partesi na",
        "matha jam hoye geche",
        "too much in my head",
        "overwhelmed লাগছে",
        "মাথা কাজ করছে না",
        "সিদ্ধান্ত নিতে পারছি না",
        "সবকিছু একসাথে মাথায় আসছে",
    ],

    # ── 19. Self-esteem / Identity issues ──────────────────
    "self_identity": [
        "ami ki chai jani na",
        "amar kono purpose nai",
        "i don't know who i am anymore",
        "life directionless",
        "lost my identity",
        "nijeke harai felechi",
        "আমি কী চাই জানি না",
        "আমি কে বুঝতে পারি না",
        "আমার কোনো পরিচয় নেই",
        "নিজেকে চিনতে পারছি না",
    ],

    # ── 20. Work burnout / Productivity depression ─────────
    "burnout_productivity": [
        "ami mentally exhausted",
        "deadline er pressure",
        "everything feels like pressure",
        "i can't keep up with work",
        "kaj korte gele panic lage",
        "kaj korte iccha kore na",
        "burnout হয়ে গেছি",
        "productivity zero",
        "কাজ করতে করতে ক্লান্ত",
        "কাজে আর আগ্রহ নেই",
    ],

    # ── 21. Comparison / Inferiority ───────────────────────
    "comparison_inferiority": [
        "ami kono kichute best na",
        "everyone is ahead of me",
        "i feel inferior",
        "i feel like a failure compared to others",
        "social media dekhe kharap lage",
        "sobai better than me",
        "অন্যদের লাইফ ভালো",
        "আমি পিছিয়ে পড়েছি",
        "নিজেকে ছোট লাগে",
        "সবাই এগিয়ে যাচ্ছে আমি না",
    ],

    # ── 22. Passive help-seeking / Indirect distress ───────
    "indirect_help": [
        "can someone listen to me",
        "help lagbe mentally",
        "how to fix my mind",
        "i need someone to talk to",
        "i want to feel okay again",
        "karo sathe kotha bolte chai",
        "আমি ঠিক হতে চাই",
        "কীভাবে নিজেকে সামলাব",
        "কাউকে বললে কি হালকা লাগবে",
        "মন ভালো করার উপায় কী",
    ],

    # ── 23. Social Media Cryptic Status ────────────────────
    "short_cryptic_status": [
        "acting happy",
        "am i the problem?",
        "broken.",
        "can't do this anymore",
        "done.",
        "emotionally exhausted",
        "empty.",
        "exhausted.",
        "faking smile",
        "feel nothing",
        "giving up",
        "invisible",
        "just want to disappear",
        "lost.",
        "mentally drained",
        "need a break",
        "nirbakar",
        "nobody cares",
        "numb.",
        "shanti nai",
        "tired.",
        "unloved",
        "worthless",
        "অভিনয়",
        "অসহ্য",
        "অন্ধকার",
        "আর কত",
        "আর না",
        "কষ্ট",
        "ক্লান্ত",
        "ক্লান্ত মন",
        "কেন বেঁচে আছি",
        "ক্ষমা",
        "পাথর মন",
        "বিদায়",
        "বিষাক্ত",
        "বিরক্ত",
        "লুকানো কষ্ট",
        "শেষ",
        "শূন্য",
        "সব মিথ্যে",
        "হাসির আড়ালে",
        "হার মেনেছি",
        "আমি কে",
        "kothao keu nei",
        "shob fake",
    ],

    # ── 24. Late-night venting ─────────────────────────────
    "late_night_venting": [
        "3 am thoughts bangla",
        "amr keno eto kosto",
        "amr life e keno emon",
        "drowning in thoughts",
        "ghum ashe na ki korbo",
        "insomnia r valo lage na",
        "kobe thik hobo",
        "late night panic attack",
        "lonely nights",
        "midnight crying",
        "mind won't shut up",
        "nijer upor ghenna",
        "nonghum",
        "overthinking killing me",
        "rait er kosto",
        "rat jagar kosto",
        "scared of the dark",
        "shob amar dosh",
        "sob kotha mone pore rat e",
        "waking up crying",
        "অতীত মনে পড়ছে",
        "অন্ধকারেই ভালো আছি",
        "আলো ভয় লাগে",
        "ওভারথিংকিং",
        "কষ্টের রাত",
        "কান্না আটকে রাখার কষ্ট",
        "কেউ শোনে না",
        "কেন আমার সাথেই এমন হয়",
        "ঘুমহীন রাত",
        "নীরব কান্না",
        "পুরনো স্মৃতি কাঁদায়",
        "বালিশ ভেজানো",
        "ভয়ানক রাত",
        "মাঝরাতে দম বন্ধ লাগে",
        "মাঝরাতের কান্না",
        "রাত শেষ হয় না",
        "রাত বাড়লে কষ্ট বাড়ে",
        "রাতে ঘুম আসে না কেন",
        "লুকিয়ে কাঁদার জায়গা",
        "সকাল দেখতে চাই না",
        "সবাই আমাকে ছেড়ে যায় কেন",
        "আমার দোষ কী ছিল",
        "আমি কি এতই খারাপ",
        "আমি কি সুখী হতে পারব না",
        "একলা রাত",
    ],

    # ── 25. Gen-Z / Nihilism Slang ─────────────────────────
    "gen_z_nihilism_banglish": [
        "anon post depression",
        "attention span sesh",
        "burnout bangla",
        "childhood trauma ruining life",
        "clown ami",
        "comparison is killing me",
        "daddy issues bangla",
        "depressed posting",
        "doom scrolling",
        "dopamine detox",
        "everyone is doing better than me",
        "feeling left behind",
        "fomo te bhugtesi",
        "gaslighting er shikar",
        "generation trauma",
        "healing is hard",
        "imposter syndrome bangla",
        "it is what it is",
        "lol ami sesh",
        "main character energy nai",
        "mental peace nai",
        "mentally unstable",
        "mommy issues bangla",
        "need therapy but broke",
        "npc life",
        "peaked in high school",
        "procrastination depression",
        "red flag",
        "ruining my own life",
        "sad boi hours",
        "sad girl hours",
        "social media anxiety",
        "toxic family",
        "toxic relationship",
        "trauma dump",
        "venting here cause nobody knows me",
        "wasting my youth",
        "ami ekti walking red flag",
        "amr life ta ekta joke",
        "self sabotage kori keno",
        "চিল নাই লাইফে",
        "জীবনটা তেজপাতা",
        "প্যারা আর প্যারা",
        "সারাদিন ফোন গুঁতাই আর কাঁদি",
        "কোনো প্রোডাক্টিভিটি নাই",
    ],

    # ── 26. Family & Society Pressure Rant ─────────────────
    "family_society_rant": [
        "abusive parents",
        "baba mar theke kosto",
        "biyer pressure",
        "career pressure",
        "chachato vai er sathe tulona",
        "comparison with cousins",
        "family trauma bangla",
        "golden child syndrome",
        "hobbys are dead",
        "kobe chakri pabo",
        "narcissistic parents bangla",
        "nijer jonno bacha hoy na",
        "nobody understands my passion",
        "passion killed by parents",
        "relative der kotha bhalolage na",
        "shob dik theke chap",
        "shobai khali judge kore",
        "shobar expectation puron korte korte klanto",
        "society is toxic",
        "strict parents ruined my life",
        "আত্মীয়দের খোঁচা",
        "গরিবের কেউ নাই",
        "টাকার জন্য অপমান",
        "টক্সিক বাবা মা",
        "পরিবার যখন শত্রু",
        "পরিবারের বড় ছেলের দায়িত্ব",
        "পকেট খালি থাকলে কেউ চেনে না",
        "বাবা মা শুধু বকে",
        "বিয়ে নিয়ে মানসিক চাপ",
        "বেকার বলে কেউ দাম দেয় না",
        "মা বাবার ঝগড়া",
        "মানসিক শান্তি নাই বাসায়",
        "মেয়ে হওয়ার কষ্ট",
        "সফল না হলে পরিবারও ছ্যাঁকা দেয়",
        "সমাজের ভয়",
        "স্বার্থপর সমাজ",
        "ঘর থেকে পালাতে চাই",
        "ছেলেদেরও কষ্ট থাকে",
        "নিজের বাসায় একা লাগে",
        "কেউ আমার কথা শোনে না",
        "আমি একটা ব্যর্থ মানুষ",
        "আমি পরিবারের হতাশা",
        "আমি বাবা মায়ের স্বপ্ন ভাঙছি",
        "আমাকে দিয়ে কিছু হবে না",
        "সবাই আমার উপর বিরক্ত",
    ],

    # ── 27. Severe Despair / Internet Cries for Help ───────
    "severe_despair_cries": [
        "I want to disappear",
        "allah amk niye jao",
        "amar hayet shesh koro",
        "amar jibon obhishopto",
        "amar mrittu dorkar",
        "amr kono future nai",
        "beyond repair",
        "can't breathe",
        "completely shattered",
        "how to disappear completely",
        "kobe morbo",
        "kono mirakel hobe na",
        "losing my mind",
        "make it stop",
        "morar upoy ki",
        "mukti chai",
        "no hope left",
        "osudh kaj kore na",
        "painless death",
        "r bachte chai na",
        "shob koshish bekar",
        "sob rasta bondho",
        "someone please help me",
        "suicide note ideas",
        "therapist o amk theek korte parbe na",
        "আমাকে সবাই মাফ করে দিবেন",
        "আমার জন্য দোয়া করবেন",
        "আমি আর পারলাম না",
        "আমি ফেটে পড়ব",
        "আমি পৃথিবীর জন্য ফিট না",
        "আমি ভিনগ্রহের মানুষ",
        "আমি শুধু একটা ভুল",
        "আমি হার মেনে নিলাম",
        "আর কোনো উপায় নেই",
        "এই দুনিয়া আমার জন্য না",
        "কেউ আমাকে বাঁচাও",
        "কেউ আমাকে চায়নি কখনো",
        "পাগল হয়ে যাচ্ছি",
        "মৃত্যু ছাড়া পথ নেই",
        "সব শেষ করে দিতে চাই",
        "লড়াই শেষ",
        "হেল্প মি",
        "হয়তো এটাই শেষ পোস্ট",
        "গুডবাই ওয়ার্ল্ড",
    ],
}

NON_DEPRESSIVE_QUERIES = {

    # ── 1. Everyday Frustrations (Mild, non-clinical annoyances) ──────────
    "everyday_frustrations": [
        # Pure Bangla
        "আজকে অনেক গরম", "রাস্তায় প্রচুর জ্যাম", "মশার জ্বালায় বাঁচি না", "কারেন্ট চলে গেছে আবার",
        "আজকে একদমই ভালো লাগছে না", "বাসায় পানি নাই", "এত রোদ কেন আজকে", "বৃষ্টিতে ভিজে গেছি",
        "জামা শুকায় নাই", "ধুলাবালিতে অবস্থা খারাপ", "জুতা ছিঁড়ে গেছে", "চশমা খুঁজে পাচ্ছি না",
        "চাবি হারিয়ে ফেলেছি", "খাবার পুড়ে গেছে", "লবণ বেশি হয়েছে তরকারিতে", "বাসে ওঠার জায়গা নাই",
        "রিকশা পাচ্ছি না", "ভাড়া বেশি চাচ্ছে", "সকালে উঠতে দেরি হয়ে গেছে", "বইটা খুঁজে পাচ্ছি না",
        # Banglish
        "ajke onek gorom", "rastay eto jam keno", "moshar jontrona r bhalo lage na", "current nai 2 ghonta dhore",
        "matha dhoreche gorome", "basay pani nai", "eto rod keno", "bristite vije gechi",
        "jama shukay nai", "dhula balite obostha kharap", "juta chire geche", "choshma pacchi na",
        "chabi haray felechi", "khabar pure geche", "lobon beshi hoise", "bus e othar jayga nai",
        "riksha pacchi na", "vara beshi chacche", "sokale uthte late hoye gelo", "boi ta pacchi na",
        # Code-mixed
        "ajke eto traffic bhai", "amar wifi kaj kortese na", "অফিসে অনেক pressure", "pc hang korche",
        "net onek slow ajke", "uber ashte late kortese", "load shedding er ki obostha", "boss ajke onnek boka diche",
        "ac theke pani portese", "phone hang kortese", "keyboard nosto hoye geche", "server down naki",
        "site load hocche na", "ki ekta boring day", "meeting e bore hocchi", "lift nosto ajke",
        "delivery late kortese", "app crash korlo keno", "laptop overheat hocche", "router e problem"
    ],

    # ── 2. General / Physical Health (Non-psychiatric) ──────────────────
    "physical_health": [
        # Pure Bangla
        "জ্বর কমানোর উপায়", "মাথা ব্যথা করছে", "দাঁত ব্যথার ওষুধ", "ওজন কমানোর ডায়েট",
        "চুল পড়া বন্ধ করার উপায়", "ঠান্ডা লেগেছে", "কাশি কমানোর সিরাপ", "পেট খারাপের ওষুধ",
        "চোখ উঠেছে কী করব", "অ্যালার্জির সমস্যা", "মুখে ব্রণের দাগ", "খুসকি দূর করার উপায়",
        "নখ ভেঙে যাচ্ছে", "কোমরে ব্যথা", "হাঁটু ব্যথার ব্যায়াম", "বমির ওষুধ",
        "গ্যাস্ট্রিকের সমস্যা", "হাত পা কামড়াচ্ছে", "চোখের নিচে কালি", "স্কিন গ্লো করার উপায়",
        # Banglish
        "jwor komanor upay", "matha betha korche ki korbo", "dath bethar osudh", "ojon komanor tips",
        "chul pora bondho korar upay", "thanda legeche", "kashi komanor syrup", "pet kharaper osudh",
        "chokh utheche ki korbo", "allergy r problem", "mukhe bron er dag", "khuski dur korar upay",
        "nokh venge jacche", "komor betha", "hathu bethar byam", "bomir osudh",
        "gastric er problem", "hat pa kamracche", "chokher niche kali", "skin glow korar upay",
        # Code-mixed
        "gastric er problem ki korbo", "hair fall solution bangla", "allergic reaction er osudh", "স্কিন কেয়ার রুটিন",
        "back pain komanor exercise", "doctor appointment kivabe nibo", "napa extra er power koto", "weight loss tips in bangla",
        "blood pressure check up", "diabetes er diet chart", "eye specialist kothay pabo", "dentist near me",
        "skin doctor in dhaka", "muscle cramp keno hoy", "vitamin c tablets", "calcium er obhab",
        "fever check korbo kivabe", "gym diet plan", "protein powder er dam", "workout routine bangla"
    ],

    # ── 3. Educational & Career (Informational/Neutral) ─────────────────
    "education_and_career": [
        # Pure Bangla
        "চাকরির খবর আজকের", "গণিত সমাধান দশম শ্রেণি", "পরীক্ষার রুটিন কবে দিবে", "ভর্তি পরীক্ষার প্রস্তুতি",
        "বোর্ড পরীক্ষার রেজাল্ট", "বিশ্ববিদ্যালয় ভর্তি বিজ্ঞপ্তি", "বাংলা ব্যাকরণ বই", "রচনা ডিজিটাল বাংলাদেশ",
        "ইংরেজি শেখার সহজ উপায়", "অনলাইনে টাকা ইনকাম", "কম্পিউটার শেখার কোর্স", "টাইপিং স্পিড বাড়ানোর উপায়",
        "সরকারি ছুটির তালিকা", "ব্যাংকের চাকরির প্রস্তুতি", "সাধারণ জ্ঞান বাংলাদেশ", "ইতিহাস বই পিডিএফ",
        "খবরের কাগজ বাংলাদেশ", "বৃত্তি পরীক্ষার রেজাল্ট", "অনুবাদ ইংরেজি থেকে বাংলা", "শব্দার্থ খুঁজুন",
        # Banglish
        "chakrir khobor ajker", "math solution class 10", "exam routine kobe dibe", "admission test er preparation",
        "board exam er result", "university admission notice", "bangla byakoron boi", "rochona digital bangladesh",
        "english shekhar sohoj upay", "online e taka income", "computer shekhar course", "typing speed baranor upay",
        "sorkari chutir talika", "bank job preparation", "sadharon gyan bangladesh", "itihas boi pdf",
        "khoborer kagoj bd", "britti porikkhar result", "translate english to bangla", "shobdartho khujun",
        # Code-mixed
        "how to write a formal email", "cv format pdf download", "interview te ki question kore", "bcs preparation kivabe nibo",
        "freelancing kivabe shuru korbo", "assignment submit korte hobe", "programming language bangla tutorial", "digital marketing course in bd",
        "ielts speaking topics", "toefl vs ielts", "presentation kivabe dibo", "excel shortcut keys bangla",
        "graphic design free course", "python code run kortese na", "job application cover letter", "linkedin profile setup",
        "upwork account approval", "fiverr gig rank korar upay", "ms word e bangla likhbo kivabe", "pdf to word converter"
    ],

    # ── 4. Food, Cooking & Recipes ──────────────────────────────────────
    "food_and_cooking": [
        # Pure Bangla
        "কাচ্চি বিরিয়ানি রেসিপি", "ডিম রান্নার সহজ উপায়", "গরুর মাংস ভুনা", "কাছাকাছি ভালো রেস্টুরেন্ট",
        "খিচুড়ি রান্নার নিয়ম", "ইলিশ মাছ ভাজা", "পায়েস রেসিপি", "চা বানানোর নিয়ম",
        "ফুচকা বানানোর রেসিপি", "চটপটি মশলা", "মিষ্টি দই", "রসগোল্লা বানানোর উপায়",
        "রুটি নরম করার উপায়", "পরোটা রেসিপি", "মুরগির রোস্ট", "তেহারি রান্না",
        "সবজি ভাজি", "ডাল রান্নার রেসিপি", "শুটকি ভর্তা", "বেগুন ভাজা",
        # Banglish
        "kacchi biryani recipe", "dim rannar sohoj upay", "gorur mangsho vuna", "kacha kachi valo restaurant",
        "khichuri rannar niyom", "ilish mach bhaja", "payesh recipe", "cha bananor niyom",
        "fuchka bananor recipe", "chotpoti moshla", "mishti doi", "roshogolla bananor upay",
        "ruti norom korar upay", "porota recipe", "murgir roast", "tehari ranna",
        "sobji bhaji", "dal rannar recipe", "shutki bhorta", "begun bhaja",
        # Code-mixed
        "chicken biryani order korbo", "foodpanda voucher code", "kfc chicken price bd", "pizza bananor niyom",
        "best street food in dhaka", "buffet dinner price", "diet food plan bangla", "burger king menu",
        "coffee bananor shortcut", "pasta ranna korbo kivabe", "cake recipe without oven", "soup bananor niyom",
        "dominos pizza order", "kachigai menu price", "sultan dine kacchi review", "online grocery order",
        "bbq chicken recipe", "shawarma bananor niyom", "ice cream recipe at home", "french fries kivabe banay"
    ],

    # ── 5. Tech, Gadgets & Digital Tasks ────────────────────────────────
    "tech_and_gadgets": [
        # Pure Bangla
        "নতুন ফোনের দাম", "পাসওয়ার্ড ভুলে গেলে করণীয়", "বিকাশ থেকে টাকা পাঠানোর নিয়ম", "ভোটার আইডি কার্ড চেক",
        "জন্ম নিবন্ধন যাচাই", "পাসপোর্ট স্ট্যাটাস চেক", "ড্রাইভিং লাইসেন্স নবায়ন", "টিন সার্টিফিকেট ডাউনলোড",
        "ওয়াইফাই স্পিড টেস্ট", "ল্যাপটপ গরম হলে কী করব", "পেনড্রাইভ ফরম্যাট করার নিয়ম", "মেমোরি কার্ড লক",
        "বিকাশ পিন রিসেট", "নগদ একাউন্ট খোলার নিয়ম", "রকেট ব্যালেন্স চেক", "বিদ্যুৎ বিল দেওয়ার নিয়ম",
        "গ্যাস বিল চেক", "পানির বিল বিকাশ", "নতুন সিম কেনার নিয়ম", "এমবি অফার গ্রামীণফোন",
        # Banglish
        "notun phone er dam", "password vule gele ki korbo", "bkash theke taka pathanor niyom", "voter id card check",
        "jonmo nibondhon jachai", "passport status check", "driving license nobayon", "tin certificate download",
        "wifi speed test", "laptop gorom hole ki korbo", "pendrive format korar niyom", "memory card lock",
        "bkash pin reset", "nagad account kholar niyom", "rocket balance check", "biddut bill dewar niyom",
        "gas bill check", "panir bill bkash", "notun sim kenar niyom", "mb offer gp",
        # Code-mixed
        "best budget phone 2024", "wifi password change korbo kivabe", "iphone 15 price in bd", "laptop screen black hoye geche",
        "facebook account delete korar upay", "youtube video download software", "ai image generator free", "nagad account open",
        "gmail password recovery", "instagram reels download", "whatsapp backup restore", "capcut template link",
        "pc build under 50k", "graphics card dam koto", "ssd upgrade korbo", "router setup kivabe kore",
        "smart watch price bd", "earbuds under 2000 tk", "power bank best brand", "android update problem"
    ],

    # ── 6. Entertainment, Sports & Pop Culture ──────────────────────────
    "entertainment_and_sports": [
        # Pure Bangla
        "আজকের খেলার খবর", "নতুন বাংলা নাটক", "মজার ভিডিও", "সাকিব আল হাসানের খবর",
        "ক্রিকেট খেলার লাইভ স্কোর", "ফুটবল বিশ্বকাপ", "নতুন সিনেমা কবে আসবে", "গানের লিরিক্স",
        "ভূতের গল্প", "মজার জোকস", "আজকের রাশিফল", "নায়ক শাকিব খানের ছবি",
        "বাংলা ব্যান্ডের গান", "কবিতা আবৃত্তি", "ভ্রমণ কাহিনী", "তাস খেলার নিয়ম",
        "লুডু খেলা", "দাবা খেলার নিয়ম", "নতুন কার্টুন ভিডিও", "ম্যাজিক ট্রিকস",
        # Banglish
        "ajker khelar khobor", "notun bangla natok", "mojar video", "sakib al hasan news",
        "cricket khelar live score", "football world cup", "notun cinema kobe ashbe", "ganer lyrics",
        "vuter golpo", "mojar jokes", "ajker rashifol", "nayok shakib khaner chobi",
        "bangla band er gan", "kobita abritti", "vromon kahini", "tash khelar niyom",
        "ludu khela", "daba khelar niyom", "notun cartoon video", "magic tricks",
        # Code-mixed
        "cricket live score", "bpl match today", "netflix new series", "avengers endgame bangla subtitle",
        "korean drama dubbed in bangla", "cineplex ticket price", "viral tiktok video", "messi new team news",
        "ronaldo hattrick video", "ipl points table", "spotify premium free", "bts new song lyrics",
        "anime download link", "naruto episode 1", "marvel movies list order", "blockbuster cinema schedule",
        "coke studio bangla song", "roasting video bd", "funny cat compilation", "gaming channel live"
    ],

    # ── 7. Travel, Navigation & Weather ─────────────────────────────────
    "travel_and_navigation": [
        # Pure Bangla
        "আজকের আবহাওয়া কেমন", "ট্রেনের টিকিট কাটার নিয়ম", "কক্সবাজার যাওয়ার বাস", "বৃষ্টি কবে হবে",
        "সিলেটের দর্শনীয় স্থান", "সেন্টমার্টিন জাহাজ ভাড়া", "হোটেল বুকিং নিয়ম", "পাসপোর্ট অফিস কোথায়",
        "ভিসা আবেদন কেন্দ্র", "বিমান বাংলাদেশ টিকিট", "বাসের টিকিট বুকিং", "লঞ্চের কেবিন ভাড়া",
        "রাস্তার ম্যাপ", "গাড়ি ভাড়ার রেট", "ভ্রমণ গাইড", "পাহাড়ে ঘোরার জায়গা",
        "ঐতিহাসিক স্থান বাংলাদেশ", "পার্কের টিকিট কত", "চিড়িয়াখানা খোলার সময়", "যাদুঘর বন্ধ কবে",
        # Banglish
        "ajker abohawa kemon", "train er ticket katar niyom", "coxs bazar jabar bus", "bristi kobe hobe",
        "sylhet er dorshoniyo sthan", "saint martin jahaj vara", "hotel booking niyom", "passport office kothay",
        "visa abedon kendro", "biman bangladesh ticket", "bus er ticket booking", "launch er cabin vara",
        "rastar map", "gari varar rate", "vromon guide", "pahare ghorar jayga",
        "oitihashik sthan bangladesh", "park er ticket koto", "chiriakhana kholar shomoy", "jadughor bondho kobe",
        # Code-mixed
        "weather update dhaka", "uber fare estimate", "google maps dhaka", "metro rail schedule bd",
        "sajek valley tour package", "us bangla flight ticket", "bdtickets bus booking", "shohoz train ticket",
        "indian visa application online", "dubai flight schedule", "coxs bazar 5 star hotel", "resort in sreemangal",
        "pathao bike vara", "brtc bus route", "hatirjheel water taxi time", "sada pathor tour plan",
        "bandarban guide number", "kuakata bus counter", "malaysia calling visa info", "ticket checking system"
    ],

    # ── 8. Shopping & Finance ───────────────────────────────────────────
    "shopping_and_finance": [
        # Pure Bangla
        "আজকের সোনার দাম", "শেয়ার বাজার খবর", "ডলার রেট কত", "সঞ্চয়পত্র কেনার নিয়ম",
        "নতুন শার্টের ডিজাইন", "শাড়ির কালেকশন", "জুতার দাম", "শীতের কাপড়ের দাম",
        "মুদি বাজারের তালিকা", "চালের দাম কত", "সবজির বাজার দর", "মুরগির দাম আজকে",
        "ব্যাংক একাউন্ট চেক", "লোন নেওয়ার নিয়ম", "ক্রেডিট কার্ড অফার", "ডিপিএস খোলার নিয়ম",
        "কসমেটিকস এর দাম", "লিপস্টিক কালার", "পারফিউম দাম", "ঘড়ির ডিজাইন",
        # Banglish
        "ajker sonar dam", "share bazar khobor", "dollar rate koto", "sonchoypotro kenar niyom",
        "notun shirt er design", "sharir collection", "jutar dam", "shiter kaporer dam",
        "mudi bazarer talika", "chaler dam koto", "sobjir bazar dor", "murgir dam ajke",
        "bank account check", "loan newar niyom", "credit card offer", "dps kholar niyom",
        "cosmetics er dam", "lipstick color", "perfume dam", "ghorir design",
        # Code-mixed
        "daraz 11.11 sale offer", "chaldal grocery order", "tshirt brand bd", "sneakers for men price",
        "winter jacket collection", "gold price today in bd", "exchange rate bd", "stock market index",
        "student bank account details", "islami bank app login", "city bank helpline", "visa card apply",
        "shwapno super shop offer", "agora outlet near me", "arong panjabi price", "apex shoe online",
        "skincare products order", "sunscreen price bd", "facewash best brand", "makeup brush set"
    ],

    # ── 9. Home & Lifestyle ─────────────────────────────────────────────
    "home_and_lifestyle": [
        # Pure Bangla
        "ঘর সাজানোর উপায়", "কাপড়ের দাগ তোলার নিয়ম", "ফ্রিজ পরিষ্কার করার উপায়", "পোকামাকড় দূর করার উপায়",
        "বাগান করার নিয়ম", "ছাদে গাছ লাগানো", "ফার্নিচার ডিজাইন", "পর্দার কাপড়ের দাম",
        "রং করার খরচ", "টাইলস পরিষ্কার করার নিয়ম", "গ্যাস সিলিন্ডার দাম", "বই পড়ার উপকারিতা",
        "সকালের রুটিন", "বাচ্চাদের খেলনা", "নামাজের সময়সূচি", "কোরআন তেলাওয়াত",
        "রোজা রাখার নিয়ত", "ইফতারের সময়", "সেহরির শেষ সময়", "দোয়া ও জিকির",
        # Banglish
        "ghor sajanor upay", "kaporer dag tolar niyom", "fridge porishkar korar upay", "pokamakor dur korar upay",
        "bagan korar niyom", "chade gach lagano", "furniture design", "pordar kaporer dam",
        "rong korar khoroch", "tiles porishkar korar niyom", "gas cylinder dam", "boi porar upokarita",
        "sokaler routine", "bacchader khelna", "namazer somoysuchi", "quran telawat",
        "roja rakhar niyot", "iftar er shomoy", "sehrir shesh shomoy", "doa o jikir",
        # Code-mixed
        "home decor ideas bd", "interior design cost dhaka", "room cleaning hacks", "kitchen cabinet price",
        "indoor plants shop", "balcony garden setup", "ikea products in bd", "sofa cover design",
        "morning routine for productivity", "time management tips", "kids story book", "prayer time dhaka",
        "ramadan calendar bd", "islamic quotes bangla", "motivation books pdf", "bedsheet cotton price",
        "wall paint colors", "plumbing service bd", "electrician near me", "home shifting service"
    ],

    # ── 10. Social Chitchat & Everyday Phrasing ─────────────────────────
    "general_chitchat": [
        # Pure Bangla
        "কী খবর তোমার", "কোথায় আছো এখন", "শুভ জন্মদিন", "খাবার খেয়েছ",
        "অনেক দিন পর কথা হচ্ছে", "আজকে কী প্ল্যান", "কবে আসবে", "বিকালে দেখা করব",
        "চা খেতে যাবা", "লাঞ্চ করা হয়েছে", "ঘুম থেকে কবে উঠলে", "শুভ সকাল",
        "শুভ রাত্রি", "ঈদ মোবারক", "নববর্ষের শুভেচ্ছা", "অভিনন্দন",
        "ভালো থেকো", "পরে কথা হবে", "ফোন ধরো", "রিপ্লাই দাও",
        # Banglish
        "ki khobor tomar", "kothay acho ekhon", "shuvo jonmodin", "khabar kheyecho",
        "onek din por kotha hocche", "ajke ki plan", "kobe ashbe", "bikale dekha korbo",
        "cha khete jaba", "lunch kora hoyeche", "ghum theke kobe uthle", "shuvo sokal",
        "shuvo ratri", "eid mobarak", "noboborsho r shuvechha", "ovinondon",
        "valo theko", "pore kotha hobe", "phone dhoro", "reply dao",
        # Code-mixed
        "congratulations bhai", "meeting e achi pore call dicchi", "online e asho", "office theke ber holam",
        "good night", "happy anniversary", "video call e asho", "whatsapp e knock dao",
        "text check koro", "pic send koro", "busy naki ekhon", "class e achi",
        "free hoye call daw", "miss you bro", "best of luck", "have a safe journey",
        "take care", "see you tomorrow", "weekend plan ki", "party kobe diba"
    ]
}
# Count totals
total_dep     = sum(len(v) for v in DEPRESSIVE_QUERIES.values())
total_non_dep = sum(len(v) for v in NON_DEPRESSIVE_QUERIES.values())

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import TextFormatter

import pandas as pd
import time
import re
import os
import random

from tqdm import tqdm
from langdetect import detect

# ============================================================
# CONFIG
# ============================================================

YOUTUBE_API_KEY = "PUT YOUR YOUTUBE API KEY HERE"

youtube = build(
    'youtube',
    'v3',
    developerKey=YOUTUBE_API_KEY
)

RAW_PATH = './BanglishDetect/data/raw/youtube_collected_raw.csv'

CATEGORY_SAVE_DIR = "./BanglishDetect/data/categories"
PROGRESS_PATH = "./BanglishDetect/data/query_progress.csv"
VIDEO_QUERY_PATH = "./BanglishDetect/data/query_video_progress.csv"

MAX_UNITS = 200000
MAX_ROWS = 200000
CHECKPOINT_EVERY = 1000

SEARCH_COST = 100
COMMENT_COST = 1
VIDEO_META_COST = 1

# ============================================================
# OPTIONAL EMOTICONS
# ============================================================

EMOTICONS = [
    "🙂", "😊", "😢", "😭", "😔", "😞", "😡",
    "❤️", "💔", "🥺", "😩", "😫", "😴", "😅",
    ":)", ":(", ":D", ":'(",
    "lol", "lmao", "haha"
]

# ============================================================
# IMPORT YOUR QUERY BANK HERE
# ============================================================

# PASTE YOUR:
# CELL — Comprehensive Bengali Depression Query Bank


DEPRESSIVE_QUERIES = {


}

NON_DEPRESSIVE_QUERIES = {

    
}
# ============================================================
# CATEGORY TRACKING
# ============================================================

category_stats = {}

for cat, qlist in DEPRESSIVE_QUERIES.items():

    category_stats[f"dep::{cat}"] = {

        'queries': len(qlist),
        'videos': 0,
        'comments': 0

    }

for cat, qlist in NON_DEPRESSIVE_QUERIES.items():

    category_stats[f"non::{cat}"] = {

        'queries': len(qlist),
        'videos': 0,
        'comments': 0

    }

# ============================================================
# SEARCH VIDEOS
# ============================================================

def search_videos(query, max_results=5):

    for attempt in range(3):

        try:

            res = youtube.search().list(
                part="snippet",
                q=query,
                type="video",
                relevanceLanguage="bn",
                maxResults=max_results,
                videoDuration="medium",
                order="relevance"
            ).execute()

            return [
                item['id']['videoId']
                for item in res.get('items', [])
            ]

        except Exception as e:

            print(f"Search retry {attempt+1}: {e}")

            time.sleep(
                2 * (attempt + 1)
            )

    return []

# ============================================================
# GET VIDEO METADATA
# ============================================================

def get_video_metadata(video_id):

    try:

        res = youtube.videos().list(
            part="snippet,statistics",
            id=video_id
        ).execute()

        if not res.get('items'):
            return {}

        item = res['items'][0]

        return {

            'title':
                item['snippet'].get('title', ''),

            'channel':
                item['snippet'].get('channelTitle', ''),

            'published_at':
                item['snippet'].get('publishedAt', ''),

            'views':
                item['statistics'].get('viewCount', 0),

            'comments_count':
                item['statistics'].get('commentCount', 0),

        }

    except Exception:

        return {}

# ============================================================
# GET TRANSCRIPT
# ============================================================

def get_transcript(video_id):

    try:

        transcript = YouTubeTranscriptApi.get_transcript(
            video_id,
            languages=['bn', 'en']
        )

        formatter = TextFormatter()

        transcript_text = formatter.format_transcript(
            transcript
        )

        return transcript_text

    except Exception:

        return ""

# ============================================================
# GET COMMENTS
# ============================================================

def get_comments(video_id, max_per_video=200):

    comments = []

    page_token = None

    try:

        while len(comments) < max_per_video:

            res = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,
                pageToken=page_token,
                textFormat="plainText",
                order="relevance"
            ).execute()

            for item in res.get('items', []):

                snippet = item['snippet']['topLevelComment']['snippet']

                comments.append({

                    'text':
                        snippet.get('textDisplay', ''),

                    'likes':
                        snippet.get('likeCount', 0),

                    'published_at':
                        snippet.get('publishedAt', ''),

                    'reply_count':
                        item['snippet'].get(
                            'totalReplyCount',
                            0
                        ),

                    'author_channel':
                        snippet.get(
                            'authorChannelId',
                            {}
                        ).get('value', '')

                })

                if len(comments) >= max_per_video:
                    break

            page_token = res.get('nextPageToken')

            if not page_token:
                break

    except Exception:
        pass

    return comments

# ============================================================
# BENGALI DETECTION
# ============================================================

def is_bengali(text, min_chars=5):

    text = str(text)

    bn_chars = len(
        re.findall(r'[\u0980-\u09FF]', text)
    )

    if bn_chars >= min_chars:
        return True

    try:

        lang = detect(text)

        if lang == 'bn':
            return True

    except:
        pass

    return False

# ============================================================
# BANGLISH DETECTOR
# ============================================================

def is_banglish(text):

    text = str(text)

    has_english = bool(
        re.search(r'[a-zA-Z]', text)
    )

    has_bn = bool(
        re.search(r'[\u0980-\u09FF]', text)
    )

    return has_english and has_bn

# ============================================================
# QUALITY FILTER
# ============================================================

def is_meaningful(text, min_words=3):

    text = str(text).strip()

    if len(text) < 10:
        return False

    words = text.split()

    if len(words) < min_words:
        return False

    # Emoji-only

    if re.match(
        r'^[\U0001F600-\U0001FFFF\s]+$',
        text
    ):
        return False

    # Repeated spam

    if re.search(r'(.)\1{6,}', text):
        return False

    return True

# ============================================================
# CRASH SAFE SAVE
# ============================================================

def save_checkpoint(data):

    temp_path = RAW_PATH + ".tmp"

    pd.DataFrame(data).to_csv(
        temp_path,
        index=False
    )

    os.replace(
        temp_path,
        RAW_PATH
    )
# ============================================================
# SAVE QUERY PROGRESS
# ============================================================

def save_query_progress(query):

    global completed_queries

    completed_queries.add(query)

    pd.DataFrame({

        'query': list(completed_queries)

    }).to_csv(

        PROGRESS_PATH,

        index=False

    )

# ============================================================
# SAVE QUERY-VIDEO PROGRESS
# ============================================================

def save_query_video_progress(query, video_id):

    global processed_query_videos

    processed_query_videos.add(

        (query, video_id)

    )

    rows = [

        {

            'query': q,

            'video_id': v

        }

        for q, v in processed_query_videos

    ]

    pd.DataFrame(rows).to_csv(

        VIDEO_QUERY_PATH,

        index=False

    )
# ============================================================
# RESUME SUPPORT
# ============================================================

if os.path.exists(RAW_PATH):

    existing_df = pd.read_csv(RAW_PATH)

    all_comments = existing_df.to_dict(
        'records'
    )

    seen_texts = set(
        existing_df['text']
        .astype(str)
        .tolist()
    )

    seen_video_ids = set(
        existing_df['video_id']
        .astype(str)
        .tolist()
    )

    print("=" * 60)
    print("RESUMING EXISTING COLLECTION")
    print("=" * 60)

    print(
        f"Loaded comments: "
        f"{len(all_comments):,}"
    )

    print(
        f"Known videos: "
        f"{len(seen_video_ids):,}"
    )

else:

    all_comments = []

    seen_texts = set()

    seen_video_ids = set()

    print("=" * 60)
    print("STARTING FRESH COLLECTION")
    print("=" * 60)

# ============================================================
# LOAD QUERY PROGRESS
# ============================================================

if os.path.exists(PROGRESS_PATH):

    progress_df = pd.read_csv(PROGRESS_PATH)

    completed_queries = set(

        progress_df['query'].astype(str)

    )

else:

    completed_queries = set()

# ============================================================
# LOAD QUERY-VIDEO PROGRESS
# ============================================================

if os.path.exists(VIDEO_QUERY_PATH):

    qv_df = pd.read_csv(VIDEO_QUERY_PATH)

    processed_query_videos = set(

        zip(

            qv_df['query'].astype(str),

            qv_df['video_id'].astype(str)

        )

    )

else:

    processed_query_videos = set()
# ============================================================
# API TRACKING
# ============================================================

api_units_used = 0

# ============================================================
# MASTER COLLECTION FUNCTION
# ============================================================

def collect_from_queries(
    query_dict,
    tentative_label,
    label_name,
    max_videos_per_query=3,
    max_comments_per_video=200,
    balance_queries=True,
    max_queries_per_category=25
):

    global api_units_used
    global all_comments
    global seen_texts
    global seen_video_ids
    global category_stats

    total_queries = sum(
        len(v)
        for v in query_dict.values()
    )

    print("\n" + "=" * 60)

    print(
        f"STARTING: "
        f"{label_name.upper()}"
    )

    print(
        f"Categories: "
        f"{len(query_dict)}"
    )

    print(
        f"Queries: "
        f"{total_queries}"
    )

    print("=" * 60)

    for category, queries in query_dict.items():

        category_key = (

            f"dep::{category}"

            if tentative_label == 1

            else f"non::{category}"

        )

        print("\n" + "-" * 60)

        print(f"CATEGORY: {category}")

        print(
            f"Queries: {len(queries)}"
        )

        print("-" * 60)

        # ====================================================
        # BALANCE LARGE CATEGORIES
        # ====================================================

        if balance_queries:

            if len(queries) > max_queries_per_category:

                queries = random.sample(

                    queries,

                    max_queries_per_category

                )

        random.shuffle(queries)

        # ====================================================
        # PROCESS QUERIES
        # ====================================================

        for query in queries:
            # =================================================
            # SKIP COMPLETED QUERY
            # =================================================
            
            if query in completed_queries:
            
                print(f"⏭ Skipping completed query: {query}")
            
                continue

            if api_units_used >= MAX_UNITS:

                print("\n⚠️ API limit reached.")
                return

            if len(all_comments) >= MAX_ROWS:

                print("\n⚠️ MAX_ROWS reached.")
                return

            print(f"\n🔎 Searching: {query}")

            # =================================================
            # SEARCH VIDEOS
            # =================================================

            video_ids = search_videos(
                query,
                max_results=5
            )

            api_units_used += SEARCH_COST

            # =================================================
            # REMOVE DUPLICATES
            # =================================================

            new_videos = [

                v for v in video_ids
            
                if (
                    v not in seen_video_ids
                    and
                    (query, v) not in processed_query_videos
                )
            
            ]

            if not new_videos:
                continue

            # =================================================
            # PROCESS VIDEOS
            # =================================================

            for vid_id in tqdm(
                new_videos[:max_videos_per_query]
            ):

                if api_units_used >= MAX_UNITS:
                    return

                seen_video_ids.add(vid_id)
                save_query_video_progress(
                    query,
                    vid_id
                )
                category_stats[
                    category_key
                ]['videos'] += 1

                # --------------------------------------------
                # VIDEO META
                # --------------------------------------------

                meta = get_video_metadata(
                    vid_id
                )

                api_units_used += VIDEO_META_COST

                # --------------------------------------------
                # TRANSCRIPT
                # --------------------------------------------

                transcript_text = get_transcript(
                    vid_id
                )

                # --------------------------------------------
                # COMMENTS
                # --------------------------------------------

                comments = get_comments(
                    vid_id,
                    max_per_video=max_comments_per_video
                )

                api_units_used += COMMENT_COST

                # --------------------------------------------
                # PROCESS COMMENTS
                # --------------------------------------------

                for c in comments:

                    if len(all_comments) >= MAX_ROWS:

                        print(
                            "\n⚠️ MAX_ROWS reached."
                        )

                        return

                    text = str(
                        c['text']
                    ).strip()

                    # ----------------------------------------
                    # FILTERS
                    # ----------------------------------------

                    if not is_bengali(text):
                        continue

                    if not is_meaningful(text):
                        continue

                    if text in seen_texts:
                        continue

                    seen_texts.add(text)

                    category_stats[
                        category_key
                    ]['comments'] += 1

                    # ----------------------------------------
                    # SAVE RECORD
                    # ----------------------------------------

                    all_comments.append({

                        # ====================
                        # COMMENT
                        # ====================

                        'text':
                            text,

                        'likes':
                            c['likes'],

                        'published_at':
                            c['published_at'],

                        'reply_count':
                            c['reply_count'],

                        'author_channel':
                            c['author_channel'],

                        # ====================
                        # VIDEO
                        # ====================

                        'video_id':
                            vid_id,

                        'title':
                            meta.get(
                                'title',
                                ''
                            ),

                        'channel':
                            meta.get(
                                'channel',
                                ''
                            ),

                        'video_views':
                            meta.get(
                                'views',
                                0
                            ),

                        'video_comment_count':
                            meta.get(
                                'comments_count',
                                0
                            ),

                        'video_published_at':
                            meta.get(
                                'published_at',
                                ''
                            ),

                        # ====================
                        # TRANSCRIPT
                        # ====================

                        'transcript':
                            transcript_text[:5000],

                        # ====================
                        # LABELS
                        # ====================

                        'tentative_label':
                            tentative_label,

                        'label_source':
                            label_name,

                        'super_category':
                            (
                                'depressive'
                                if tentative_label == 1
                                else 'non_depressive'
                            ),

                        'category':
                            category,

                        'query':
                            query,

                        # ====================
                        # FEATURES
                        # ====================

                        'is_banglish':
                            is_banglish(text),

                        'has_emoticon':
                            any(
                                em in text
                                for em in EMOTICONS
                            ),

                        'text_length':
                            len(text),

                        'word_count':
                            len(
                                text.split()
                            ),

                    })

                    # ----------------------------------------
                    # CHECKPOINT
                    # ----------------------------------------

                    if (
                        len(all_comments)
                        % CHECKPOINT_EVERY
                        == 0
                    ):

                        save_checkpoint(
                            all_comments
                        )

                        print(
                            f"\n💾 Checkpoint saved:"
                            f" {len(all_comments):,}"
                        )

                # --------------------------------------------
                # RATE LIMIT
                # --------------------------------------------

                time.sleep(
                    random.uniform(
                        0.5,
                        1.5
                    )
                )

            # =================================================
            # PROGRESS
            # =================================================

            print(
                f"\nCollected: "
                f"{len(all_comments):,}"
            )

            print(
                f"API Units: "
                f"{api_units_used:,}"
            )

            print(
                f"Category comments: "
                f"{category_stats[category_key]['comments']:,}"
            )

# ============================================================
# START COLLECTION
# ============================================================

print("\nCOLLECTING DEPRESSIVE CONTENT...")

collect_from_queries(

    DEPRESSIVE_QUERIES,

    tentative_label=1,

    label_name='depressive'

)

# ============================================================

print("\nCOLLECTING NON-DEPRESSIVE CONTENT...")

collect_from_queries(

    NON_DEPRESSIVE_QUERIES,

    tentative_label=0,

    label_name='non_depressive'

)

# ============================================================
# FINAL SAVE
# ============================================================

df_collected = pd.DataFrame(
    all_comments
)

save_checkpoint(all_comments)

# ============================================================
# SAVE CATEGORY CSVs
# ============================================================

os.makedirs(
    CATEGORY_SAVE_DIR,
    exist_ok=True
)

for cat in df_collected['category'].unique():

    sub = df_collected[
        df_collected['category'] == cat
    ]

    sub.to_csv(

        f"{CATEGORY_SAVE_DIR}/{cat}.csv",

        index=False

    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n" + "=" * 60)

print("COLLECTION COMPLETE")

print("=" * 60)

print(
    f"Total comments: "
    f"{len(df_collected):,}"
)

print(
    f"Unique videos: "
    f"{len(seen_video_ids):,}"
)

print(
    f"API units used: "
    f"{api_units_used:,}/10,000"
)

print(
    f"Depressive: "
    f"{(df_collected['tentative_label']==1).sum():,}"
)

print(
    f"Non-depressive: "
    f"{(df_collected['tentative_label']==0).sum():,}"
)

print(f"\nSaved: {RAW_PATH}")

# ============================================================
# EMOTION SIGNAL ANALYSIS
# ============================================================

em_count = sum(

    any(em in str(t) for em in EMOTICONS)

    for t in df_collected['text']

)

bn_count = sum(

    bool(
        re.search(r'[a-zA-Z]', str(t))
        and re.search(r'[\u0980-\u09FF]', str(t))
    )

    for t in df_collected['text']

)

el_count = sum(

    bool(
        re.search(r'(.)\1{2,}', str(t))
    )

    for t in df_collected['text']

)

print("\nEMOTION SIGNALS")

print("=" * 60)

print(

    f"Emoticons: "

    f"{em_count:,} "

    f"({100*em_count/len(df_collected):.1f}%)"

)

print(

    f"Banglish: "

    f"{bn_count:,} "

    f"({100*bn_count/len(df_collected):.1f}%)"

)

print(

    f"Elongation: "

    f"{el_count:,} "

    f"({100*el_count/len(df_collected):.1f}%)"

)

# ============================================================
# CATEGORY BREAKDOWN
# ============================================================

print("\n")

print("=" * 60)

print("CATEGORY BREAKDOWN")

print("=" * 60)

for cat, stats in sorted(

    category_stats.items(),

    key=lambda x: x[1]['comments'],

    reverse=True

):

    print(

        f"{cat:40}"

        f" | Queries: {stats['queries']:4}"

        f" | Videos: {stats['videos']:4}"

        f" | Comments: {stats['comments']:6}"

    )

# ============================================================
# QUERY BANK STATS
# ============================================================

total_dep = sum(
    len(v)
    for v in DEPRESSIVE_QUERIES.values()
)

total_non_dep = sum(
    len(v)
    for v in NON_DEPRESSIVE_QUERIES.values()
)

print("\n")

print("=" * 60)

print("QUERY BANK SUMMARY")

print("=" * 60)

print(
    f"Depressive categories: "
    f"{len(DEPRESSIVE_QUERIES)}"
)

print(
    f"Depressive queries: "
    f"{total_dep}"
)

print(
    f"Non-depressive categories: "
    f"{len(NON_DEPRESSIVE_QUERIES)}"
)

print(
    f"Non-depressive queries: "
    f"{total_non_dep}"
)

print(
    f"Grand total queries: "
    f"{total_dep + total_non_dep}"
)

print("\nDONE.")
